# %%
# import packages 
# %run query_functions.py

# %%
insert_into_database() # issue, needed to be logged in everytime we wanna insert - to be solved
# Out:
# 'Database Loaded Successfully'

# %%
query_data()
# Out:
#                                               job_title  \
# 0                        Intern, AI researcher for AIOT
# 1                        Business Development Assistant
# 2                              Software Engineer Intern
# 3                 UI / UX Designer and QA Tester Intern
# 4     Adhoc / Flexible Programming Job (Python, Java...
# ...                                                 ...
# 2407  Data Engineer - Marketplace Intelligence and D...
# 2408     Full Stack Software Engineer Intern (6 months)
# 2409  Machine Learning Specialist, IgniteTech (Remot...
# 2410  Software Engineer (Smart Operation) - Global P...
# 2411              Software Engineer, Security, Payments
#
#                                             description  \
# 0     Job DescriptionThis position targets to develo...
# 1     Responsibilities:? Develop partnerships within...
# 2     Assisting in the development of web-based appl...
# 3     We are seeking a talentedUI/UX Designer and QA...
# ...
