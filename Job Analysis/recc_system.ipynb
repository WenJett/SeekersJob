# %% [markdown]
# # Preliminary work

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neighbors import NearestNeighbors
import re
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("Indeed_WebScraping\indeed_jobs_modified.csv")

# Text preprocessing
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['Job Description'])

# Function to recommend jobs based on input text
def recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer, top_n=3):
    input_vector = tfidf_vectorizer.transform([input_text])
    cosine_similarities = cosine_similarity(input_vector, tfidf_matrix).flatten()
    related_jobs_indices = cosine_similarities.argsort()[:-top_n-1:-1]
    recommended_jobs = df.iloc[related_jobs_indices]
    return recommended_jobs

# %%
# Example usage
input_text = "data science, machine learning, data analysis, ai"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                Job Title                        Company  \
# 262  Software and Applications Manager\n  JOYFULAI TECHNOLOGY PTE. LTD.
# 124              Summer Internship 2024                       Munich Re
# 23               Summer Internship 2024                       Munich Re
#
#                          Salary               Job Type   Location  \
# 262  $10,000 - $13,000 a month    Permanent, Full-time  Singapore
# 124                         NaN             Internship  Singapore
# 23                          NaN             Internship  Singapore
#
#                                        Job Description  Posted Date  \
# 262  Joyful AI, an innovative AI technology startup...  PostedToday
# 124  Summer Internship 2024 - Data Analyst & BI Int...  PostedToday
# 23   Summer Internship 2024 - Data Analyst & BI Int...  PostedToday
#
#      Today Date         Listing Date
# 262  2024-03-21  2024-03-21 00:00:00
# 124  2024-03-21  2024-03-21 00:00:00
# 23   2024-03-21  2024-03-21 00:00:00

# %%
input_text = "data science"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                     Job Title                    Company  \
# 119                 DATA ANALYTICS (Health)\n    RESOURCE HUNT PTE. LTD.
# 192                       Solution Architect                 SoftwareOne
# 286  Software Development Senior Specialist\n  NTT Data Services Pte Ltd
#
#                         Salary              Job Type          Location  \
# 119  $9,000 - $10,000 a month              Full-time         Singapore
# 192                        NaN             Full-time  Singapore 189720
# 286                        NaN  Permanent, Full-time         Singapore
#
#                                        Job Description  \
# 119  Health Analytics Manager\nJoin our team and he...
# 192  Job Function: Software & Cloud Services The ro...
# 286  S\nPosted by\nShubhansh Jaiswal\nTalent Acquis...
#
#                  Posted Date  Today Date         Listing Date
# 119        PostedJust posted  2024-03-21  2024-03-21 00:00:00
# 192  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 286              PostedToday  2024-03-21  2024-03-21 00:00:00

# %%
input_text = "data analysis"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                              Job Title                Company  \
# 167                                     Data Analyst\n  COGNOSPHERE PTE. LTD.
# 170                                     Data Analyst\n              NodeFlair
# 140  Customer Excellence Data Analytics & Reporting...                Cargill
#
#                         Salary               Job Type   Location  \
# 167  $7,000 - $14,000 a month    Permanent, Full-time  Singapore
# 170   $7,000 - $14,000 a month                    NaN  Singapore
# 140                        NaN                    NaN  Singapore
#
#                                        Job Description  \
# 167  Who Are We?\nAt HoYoverse, we are committed to...
# 170  Job Summary\n\nSalary\nS$7,000 - S$14,000 / Mo...
# 140  Job Purpose and Impact\n\nThe role of Commerci...
#
#                  Posted Date  Today Date         Listing Date
# 167  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 170  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 140   PostedPosted 1 day ago  2024-03-21  2024-03-20 00:00:00

# %%
input_text = "machine learning"
recommend_jobs(input_text, df, tfidf_matrix, tfidf_vectorizer)
# Out:
#                                      Job Title                    Company  \
# 208             Workforce Operations Analyst\n                      Apple
# 204  Quantitative Trader/Analyst Commodities\n        KS Talent Solutions
# 222                        Software Engineer\n  ETUAN MECHATRONIC PTE LTD
#
#                        Salary              Job Type   Location  \
# 208                       NaN                   NaN  Singapore
# 204                       NaN  Permanent, Full-time  Singapore
# 222  $3,500 - $4,500 a month              Full-time  Singapore
#
#                                        Job Description  \
# 208  Summary\n\nPosted: 15 Mar 2024\n\nRole Number:...
# 204  Join our client in an exciting role based in S...
# 222  Design and develops software for PLC/PC/Vision...
#
#                  Posted Date  Today Date         Listing Date
# 208  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 204  PostedPosted 2 days ago  2024-03-21  2024-03-19 00:00:00
# 222        PostedJust posted  2024-03-21  2024-03-21 00:00:00

# %% [markdown]
# # Rec system
# - cold start problem - use content based approach
#   - standard nlp process,
#   - user profiles info to start rec
#   - e.g. k-NN model
# - avoid rule based / search engine like recc system
# - lack of labels, unsupervised method
#   - PCA
# - copy paste resume in to get rec jobs: https://towardsdatascience.com/building-a-job-recommender-for-non-technical-business-roles-via-nlp-and-machine-learning-626c4039931e
# - azure cloud deployment, 10months old
#   - https://github.com/abbas99-hub/Job-Recommendation-System
#   - https://medium.com/@abbasbehrain95/creating-an-ai-powered-job-recommendation-system-50ce1cd12d36
# - microsoft resource: https://azure.microsoft.com/en-us/blog/building-recommender-systems-with-azure-machine-learning-service/

# %% [markdown]
# # TF IDF, KNN

# %%
# Load the data
data = pd.read_csv('consolidated.csv')

# %%
# Data Cleaning
def clean_text(text):
    if isinstance(text, str):
        # Remove special characters and digits
        text = re.sub(r'[^a-zA-Z\s]', '', text)
        # Convert to lowercase
        text = text.lower()
        return text
    else:
        return ""

data['clean_description'] = data['description'].apply(clean_text)

# %%
# TF-IDF Representation
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.8, min_df=0.2, ngram_range=(1, 2))
tfidf_matrix = vectorizer.fit_transform(data['clean_description'])

# %%
# Hyperparameter Tuning
parameters = {
    'n_neighbors': [5, 10, 15],
    'leaf_size': [20, 30, 40],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}

nbrs = NearestNeighbors()
grid_search = GridSearchCV(nbrs, parameters, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(tfidf_matrix)

print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 5}
# c:\Users\Michelle\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_search.py:1051: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(

# %%
# Get the best parameters from grid search
best_params = grid_search.best_params_

# Create a new instance of NearestNeighbors with the best parameters
nbrs = NearestNeighbors(n_neighbors=best_params['n_neighbors'],
                             leaf_size=best_params['leaf_size'],
                             algorithm=best_params['algorithm'])

# Fit the new NearestNeighbors model with the TF-IDF matrix
nbrs .fit(tfidf_matrix)
# Out:
# NearestNeighbors(leaf_size=20)

# %%
# Function to recommend top jobs using the new NearestNeighbors model
def recommend_jobs_with_best_params(resume_text):
    queryTFIDF = vectorizer.transform([resume_text])
    distances, indices = nbrs.kneighbors(queryTFIDF)
    matches = []
    for i, j in enumerate(indices):
        for idx in j:
            dist = round(distances[i][0], 2)
            temp = {'Job Title': data.iloc[idx]['job title'], 
                    'Company': data.iloc[idx]['company'],
                    'Salary Range': data.iloc[idx]['salary range'],
                    'Match Confidence': dist,
                    'Description': data.iloc[idx]['description']}
            matches.append(temp)
    recommended_jobs = pd.DataFrame(matches).sort_values('Match Confidence', ascending=False)
    return recommended_jobs

# %%
# Example usage
sample_resumes = [
    "Experienced software engineer proficient in Python and JavaScript.",
    "Experienced data scientist with expertise in machine learning and big data analytics.",
    "Junior software developer proficient in Java and SQL, eager to learn and contribute to innovative projects.",
    "Recent graduate with a degree in computer science, skilled in Python programming and web development.",
    "Experienced project manager with strong leadership and communication skills, adept at managing cross-functional teams."
]

for idx, resume_text in enumerate(sample_resumes, 1):
    print(f"Sample Resume {idx}:")
    print(f"Resume Text: {resume_text}")
    recommended_jobs = recommend_jobs_with_best_params(resume_text)
    print("Recommended Jobs:")
    print(recommended_jobs)
    print("\n")
# Out:
# Sample Resume 1:
# Resume Text: Experienced software engineer proficient in Python and JavaScript.
# Recommended Jobs:
#                                            Job Title  \
# 0                                Python FS Developer
# 1         Software Engineer (Python), Up to SGD$180k
# 2         Software Engineer (Python), Up to SGD$180k
# 3  Senior Software Engineer (C#, Python )/ Senior...
# 4                 Software Engineer - Python and K8s
#
#                             Company              Salary Range  \
# 0                  Snaphunt Pte Ltd    $1,000 - 1,300 monthly
# 1                       Hunter Bond                       NaN
# 2                       Hunter Bond                       NaN
# 3  STAR CAREER CONSULTING PTE. LTD.  $8,000 - $9,500 a month
# 4                         Canonical                       NaN
#
#    Match Confidence                                        Description
# 0              0.62  Leadership RoleGreat work environmentAttractiv...
# 1              0.62  Job Title: Software Engineer (Python) - Reliab...
# 2              0.62  Job Title: Software Engineer (Python) - Reliab...
# 3              0.62  Senior Software Engineer (C#, Python)/ Senior ...
# 4              0.62  Our mission is to reinvent the way companies m...
#
#
# Sample Resume 2:
# Resume Text: Experienced data scientist with expertise in machine learning and big data analytics.
# Recommended Jobs:
#                                       Job Title  \
# 0    Internship: AI Consultant (May - Aug 2024)
# 1                                  Data Analyst
# 2  Data Engineer, Sensor & Machine Learning Lab
# 3                Machine Learning and Data Lead
# 4                           Data Analyst Intern
#
#                                   Company            Salary Range  \
# 0  IBM SERVICES TALENT DELIVERY PTE. LTD.                     NaN
# 1                  PTC System (S) Pte Ltd  $1,000 - 2,500 monthly
# 2                    Changi Airport Group                     NaN
# 3                          Robert Walters                     NaN
# 4            ComfortDelGro Transportation          $1,200 monthly
#
#    Match Confidence                                        Description
# 0              0.34  • Apply generative AI machine learning and big...
# 1              0.34  We are building an AI data set. You will be co...
# 2              0.34  As a Machine Learning Data Engineer at CAG, yo...
# 3              0.34  An exciting Machine Learning and Data Lead job...
# 4              0.34  As a Data Analyst Intern at ComfortDelGro’s Pr...
#
#
# Sample Resume 3:
# Resume Text: Junior software developer proficient in Java and SQL, eager to learn and contribute to innovative projects.
# Recommended Jobs:
#                                            Job Title  \
# 0           AI Roles - Paid Internships in Singapore
# 1  [LTA-ITCD] SENIOR / EXECUTIVE AI ENGINEER / AI...
# 2  Data Analyst (Senior Role) Up to $5200 | Healt...
# 3                                     Network Intern
# 4                           Software Engineer Intern
#
#                        Company               Salary Range  Match Confidence  \
# 0                   SGInnovate                        NaN               0.7
# 1      Public Service Division                        NaN               0.7
# 2        RecruitFirst Pte. Ltd  $4,800 – $5,200 per month               0.7
# 3  Logicalis Singapore Pte Ltd       $800 - 1,500 monthly               0.7
# 4        Invigilo Technologies       $800 - 1,200 monthly               0.7
#
#                                          Description
# 0  Check our list of projects (https://central.sg...
# 1  You will harness the potential of AI in LTA. Y...
# 2  You will be leading projects in the epidemiolo...
# 3  Responsibilities:Assisting with implementation...
# 4  Join us in developing software that saves live...
#
#
# Sample Resume 4:
# Resume Text: Recent graduate with a degree in computer science, skilled in Python programming and web development.
# Recommended Jobs:
#                               Job Title                         Company  \
# 0  Algorithm Software Engineer Intern\n                         Tencent
# 1                QA Intern (Mobile App)  Comfort Transportation Pte Ltd
# 2                  QA Specialist Intern  Comfort Transportation Pte Ltd
# 3                             QA Intern  Comfort Transportation Pte Ltd
# 4                             QA Intern  Comfort Transportation Pte Ltd
#
#              Salary Range  Match Confidence  \
# 0                     NaN              0.78
# 1          $1,200 monthly              0.78
# 2  $1,000 - 1,500 monthly              0.78
# 3    $800 - 1,200 monthly              0.78
# 4  $1,000 - 1,500 monthly              0.78
#
#                                          Description
# 0  Responsibilities:\n1. Develop inference servic...
# 1  Responsibilities:Execute testing for mobile ap...
# 2  Execute testing for mobile app, from UIUX down...
# 3  Execute testing for mobile app, from UIUX down...
# 4  Execute testing for mobile app, from UIUX down...
#
#
# Sample Resume 5:
# Resume Text: Experienced project manager with strong leadership and communication skills, adept at managing cross-functional teams.
# Recommended Jobs:
#                                            Job Title  \
# 0                                 IT Project Manager
# 1                         Digital Excellence Center
# 2                          Project Management Intern
# 3  Project Manager (IT, Software, Website Develop...
# 4  Project Manager (IT, Software, Website Develop...
#
#                                          Company              Salary Range  \
# 0                               Snaphunt Pte Ltd    $3,800 - 4,500 monthly
# 1  CREDIT AGRICOLE CORPORATE AND INVESTMENT BANK  $5,000 - $8,500 a month
# 2                               Hiverlab Pte Ltd      $800 - 1,100 monthly
# 3                             The Digital Spacee    $3,000 - 5,000 monthly
# 4                             The Digital Spacee    $3,000 - 5,000 monthly
#
#    Match Confidence                                        Description
# 0              0.86  Work alongside & learn from best in class tale...
# 1              0.86  Our organization\nWithin the IT & Operations d...
# 2              0.86  We are looking for a Project intern who fits i...
# 3              0.86  Project Manager (IT, Software, Website Develop...
# 4              0.86  Project Manager (IT, Software, Website Develop...

# %%
# Longer sample resume texts
longer_sample_resumes = [
    "Highly skilled software engineer with over 8 years of experience in developing robust and scalable software solutions. Proficient in a wide range of programming languages including Python, Java, C++, and JavaScript. Experienced in full-stack web development with expertise in both front-end and back-end technologies. Strong problem-solving abilities and a passion for learning new technologies.",
    "Data scientist with a background in mathematics and statistics, possessing advanced analytical skills and expertise in machine learning algorithms. Experienced in data preprocessing, feature engineering, and model evaluation. Proficient in programming languages such as Python and R, with extensive experience in data manipulation libraries such as Pandas and NumPy. Strong communication skills and ability to present complex technical concepts to non-technical stakeholders.",
    "Seasoned full-stack developer with a focus on creating innovative and user-friendly web applications. Proficient in modern web technologies including HTML5, CSS3, JavaScript, and TypeScript. Experienced in using frameworks such as React, Angular, and Vue.js for front-end development, and Node.js and Express.js for back-end development. Skilled in database management systems including MySQL, MongoDB, and PostgreSQL. Strong understanding of Agile methodologies and best practices in software development.",
    "Recent graduate with a degree in computer science, eager to kickstart a career in software engineering. Possesses a strong foundation in computer science concepts including data structures, algorithms, and object-oriented programming. Proficient in programming languages such as Java, Python, and C#. Experience with web development technologies including HTML, CSS, and JavaScript. Strong problem-solving skills and ability to work collaboratively in team environments.",
    "Accomplished project manager with over 10 years of experience leading successful projects from initiation to completion. Skilled in project planning, resource allocation, and risk management. Experienced in working with cross-functional teams and stakeholders to achieve project objectives. Strong leadership abilities and effective communication skills. PMP certified with a proven track record of delivering projects on time and within budget."
]

# Display recommended jobs for longer sample resume texts
for idx, resume_text in enumerate(longer_sample_resumes, 1):
    print(f"Sample Resume {idx}:")
    print(f"Resume Text: {resume_text}\n")
    recommended_jobs = recommend_jobs_with_best_params(resume_text)
    print("Recommended Jobs:")
    print(recommended_jobs)
    print("\n")
# Out:
# Sample Resume 1:
# Resume Text: Highly skilled software engineer with over 8 years of experience in developing robust and scalable software solutions. Proficient in a wide range of programming languages including Python, Java, C++, and JavaScript. Experienced in full-stack web development with expertise in both front-end and back-end technologies. Strong problem-solving abilities and a passion for learning new technologies.
#
# Recommended Jobs:
#             Job Title                     Company              Salary Range  \
# 0  Software Engineer                     Randstad                       NaN
# 1  Software Engineer                     Randstad                       NaN
# 2   Software Engineer               Nicoll Curtin                       NaN
# 3         Developer\n                 PERSOLKELLY    Up to $11,000 a month
# 4   DevOps Engineer\n  D4L DATA4LIFE ASIA LIMITED  $5,000 - $7,500 a month
#
#    Match Confidence                                        Description
# 0              0.83  Attractive Salary Package\nStable Organisation...
# 1              0.83  Attractive Salary Package\nStable Organisation...
# 2              0.83  CompanyAn established global leading internet ...
# 3              0.83  We are seeking a highly skilled and motivated ...
# 4              0.83  Your future role\nContribute to the automation...
#
#
# Sample Resume 2:
# Resume Text: Data scientist with a background in mathematics and statistics, possessing advanced analytical skills and expertise in machine learning algorithms. Experienced in data preprocessing, feature engineering, and model evaluation. Proficient in programming languages such as Python and R, with extensive experience in data manipulation libraries such as Pandas and NumPy. Strong communication skills and ability to present complex technical concepts to non-technical stakeholders.
#
# Recommended Jobs:
#                                            Job Title               Company  \
# 0  Information Technology - Senior Data Scientist...    Singapore Airlines
# 1           Quantitative Research and Trading Intern          Bittesseract
# 2                                      Data Engineer          MIGSO-PCUBED
# 3                                      Data Engineer      Luxoft Singapore
# 4       Data Engineer, Sensor & Machine Learning Lab  Changi Airport Group
#
#            Salary Range  Match Confidence  \
# 0                   NaN              0.72
# 1  $800 - 1,800 monthly              0.72
# 2                   NaN              0.72
# 3                   NaN              0.72
# 4                   NaN              0.72
#
#                                          Description
# 0  Job DescriptionSIA has multiple positions for ...
# 1  The Quantitative Trading team of Bittesseract ...
# 2  About the role:Identify common issues in finan...
# 3  Mandatory Skills:Java Python SQLMandatory Skil...
# 4  As a Machine Learning Data Engineer at CAG, yo...
#
#
# Sample Resume 3:
# Resume Text: Seasoned full-stack developer with a focus on creating innovative and user-friendly web applications. Proficient in modern web technologies including HTML5, CSS3, JavaScript, and TypeScript. Experienced in using frameworks such as React, Angular, and Vue.js for front-end development, and Node.js and Express.js for back-end development. Skilled in database management systems including MySQL, MongoDB, and PostgreSQL. Strong understanding of Agile methodologies and best practices in software development.
#
# Recommended Jobs:
#                                          Job Title             Company  \
# 0                                  Web Development  Trakomatic Pte Ltd
# 1                         Robotics Engineer Intern           Augmentus
# 2                         Robotics Engineer Intern           Augmentus
# 3                         Robotics Engineer Intern           Augmentus
# 4  React/Next.js Front-End Junior Developer/Intern         Gram Circle
#
#              Salary Range  Match Confidence  \
# 0  $1,000 - 1,200 monthly              0.74
# 1    $800 - 1,000 monthly              0.74
# 2    $800 - 1,500 monthly              0.74
# 3    $800 - 1,500 monthly              0.74
# 4            $400 monthly              0.74
#
#                                          Description
# 0  Job Description for Web Development InternAs a...
# 1  About your roleDevelop software components for...
# 2  About your roleDevelop software components for...
# 3  About your roleDevelop software components for...
# 4  Responsibilities:- Collaborate with our cross-...
#
#
# Sample Resume 4:
# Resume Text: Recent graduate with a degree in computer science, eager to kickstart a career in software engineering. Possesses a strong foundation in computer science concepts including data structures, algorithms, and object-oriented programming. Proficient in programming languages such as Java, Python, and C#. Experience with web development technologies including HTML, CSS, and JavaScript. Strong problem-solving skills and ability to work collaboratively in team environments.
#
# Recommended Jobs:
#                     Job Title                         Company  \
# 0  Automation Engineer Intern          Insights Table Pte Ltd
# 1       Software Engineer-SDK                  Page Personnel
# 2          QA Engineer Intern  Comfort Transportation Pte Ltd
# 3          QA Engineer Intern  Comfort Transportation Pte Ltd
# 4        QA Specialist Intern  Comfort Transportation Pte Ltd
#
#              Salary Range  Match Confidence  \
# 0    $800 - 1,000 monthly              0.85
# 1                     NaN              0.85
# 2          $1,200 monthly              0.85
# 3    $800 - 1,200 monthly              0.85
# 4  $1,000 - 1,500 monthly              0.85
#
#                                          Description
# 0  Job Scope- Job scope includes, but is not limi...
# 1  Start-up in Singapore|AI IndustryAbout Our Cli...
# 2  Execute testing for mobile applications, from ...
# 3  Responsibilities:Execute testing for mobile ap...
# 4  Execute testing for mobile app, from UIUX down...
#
#
# Sample Resume 5:
# Resume Text: Accomplished project manager with over 10 years of experience leading successful projects from initiation to completion. Skilled in project planning, resource allocation, and risk management. Experienced in working with cross-functional teams and stakeholders to achieve project objectives. Strong leadership abilities and effective communication skills. PMP certified with a proven track record of delivering projects on time and within budget.
#
# Recommended Jobs:
#                                 Job Title                      Company  \
# 0               Assistant Project Manager           Orfeostory Pte Ltd
# 1  AI Project Manager (Blockchain) J44068  ScienTec Consulting Pte Ltd
# 2     AI Project Manager (Global) -J43918  ScienTec Consulting Pte Ltd
# 3                      IT Project Manager             Snaphunt Pte Ltd
# 4               Project Management Intern                         Wego
#
#                  Salary Range  Match Confidence  \
# 0      $1,000 - 1,300 monthly              0.55
# 1  $7,500 – $10,000 per month              0.55
# 2  $8,000 – $10,000 per month              0.55
# 3      $3,800 - 4,500 monthly              0.55
# 4        $800 - 1,500 monthly              0.55
#
#                                          Description
# 0  Job DescriptionLearn and assist in Project Man...
# 1  We are seeking for a skilled and experienced P...
# 2  Lead groundbreaking AI projects to redefine in...
# 3  Work alongside & learn from best in class tale...
# 4  We are seeking a dynamic and motivated individ...
